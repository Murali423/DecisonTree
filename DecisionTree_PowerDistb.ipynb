# %% [markdown]
# ### DecisionTree_Power Distribution

# %% [markdown]
# #### Problem Statement

# %% [markdown]
# Create Regression model which can able to predict the household power consumption based on given data values
#
# 1.date: Date in format dd/mm/yyyy
#
# 2.time: time in format hh:mm:ss
#
# 3.global_active_power: household global minute-averaged active power (in kilowatt)
#
# 4.global_reactive_power: household global minute-averaged reactive power (in kilowatt)
#
# 5.voltage: minute-averaged voltage (in volt)
#
# 6.global_intensity: household global minute-averaged current intensity (in ampere)
#
# 7.sub_metering_1: energy sub-metering No. 1 (in watt-hour of active energy). It corresponds to the kitchen, containing mainly a dishwasher, an oven and a microwave (hot plates are not electric but gas powered).
#
# 8.sub_metering_2: energy sub-metering No. 2 (in watt-hour of active energy). It corresponds to the laundry room, containing a washing-machine, a tumble-drier, a refrigerator and a light.
#
# 9.sub_metering_3: energy sub-metering No. 3 (in watt-hour of active energy). It corresponds to an electric water-heater and an air-conditioner.

# %% [markdown]
# #### Approach To Model

# %% [markdown]
# 1. Data collection
# 2. EDA
# 3. Feature Engineering
# 4. Modelling
# 5. Hyperparameter tuening
# 6. Evaluating Metrics

# %% [markdown]
# EDA and Feature Engineering for power distribution : https://github.com/Murali423/ML-assingment/blob/master/Householdpower-assignment.ipynb
#
# Can be seen in this post
#
# LinkedIn post: https://www.linkedin.com/posts/murali-divya-teja-gummadidala-machine-learning_linearridge-assignment-activity-6994367928766722048-U-LC?utm_source=share&utm_medium=member_desktop

# %%
import pandas as pd
import numpy as np

#visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\HP\Documents\ML-Assignment\ML-assingment\Regression\Household_FE.csv')
df.head()
# Out:
#    Global_active_power  Global_reactive_power  Voltage  Sub_metering_1  \
# 0             0.197943               0.049246   239.13            -0.0
# 1             0.240113              -0.000000   245.87            -0.0
# 2             0.435888               0.139043   241.34            -0.0
# 3             0.188924               0.095637   242.79            -0.0
# 4             0.252441               0.074875   242.65            -0.0
#
#    Sub_metering_2  Sub_metering_3  Year  Month  Day  Hours  Minute  \
# 0        -0.00000       -0.000000  2007     10   15     23      57
# 1        -0.00000        0.598538  2010      2   11      3      27
# 2         0.41599       -0.000000  2008      5   25     17       3
# 3        -0.00000        0.598538  2009      8    9     11      59
# 4        -0.00000       -0.000000  2008      2   19     22      53
#
#    Total_metering  Energy_minute
# 0       -0.000000       4.133333
# 1        0.632205       4.300000
# 2        0.950787      11.100000
# 3        0.632205       2.900000
# 4       -0.000000       5.666667

# %%
df.columns
# Out:
# Index(['Global_active_power', 'Global_reactive_power', 'Voltage',
#        'Sub_metering_1', 'Sub_metering_2', 'Sub_metering_3', 'Year', 'Month',
#        'Day', 'Hours', 'Minute', 'Total_metering', 'Energy_minute'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(['Energy_minute'],axis=1)
X.columns
# Out:
# Index(['Global_active_power', 'Global_reactive_power', 'Voltage',
#        'Sub_metering_1', 'Sub_metering_2', 'Sub_metering_3', 'Year', 'Month',
#        'Day', 'Hours', 'Minute', 'Total_metering'],
#       dtype='object')

# %%
y = df['Energy_minute']

# %%
y.head()
# Out:
# 0     4.133333
# 1     4.300000
# 2    11.100000
# 3     2.900000
# 4     5.666667
# Name: Energy_minute, dtype: float64

# %%
X.head()
# Out:
#    Global_active_power  Global_reactive_power  Voltage  Sub_metering_1  \
# 0             0.197943               0.049246   239.13            -0.0
# 1             0.240113              -0.000000   245.87            -0.0
# 2             0.435888               0.139043   241.34            -0.0
# 3             0.188924               0.095637   242.79            -0.0
# 4             0.252441               0.074875   242.65            -0.0
#
#    Sub_metering_2  Sub_metering_3  Year  Month  Day  Hours  Minute  \
# 0        -0.00000       -0.000000  2007     10   15     23      57
# 1        -0.00000        0.598538  2010      2   11      3      27
# 2         0.41599       -0.000000  2008      5   25     17       3
# 3        -0.00000        0.598538  2009      8    9     11      59
# 4        -0.00000       -0.000000  2008      2   19     22      53
#
#    Total_metering
# 0       -0.000000
# 1        0.632205
# 2        0.950787
# 3        0.632205
# 4       -0.000000

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.33,random_state=42)

# %%
X_train.head()
# Out:
#        Global_active_power  Global_reactive_power  Voltage  Sub_metering_1  \
# 23990             0.167505               0.077479   236.26            -0.0
# 8729              0.233211              -0.000000   239.62            -0.0
# 3451              0.615852               0.114589   242.61            -0.0
# 2628              0.190225              -0.000000   241.53            -0.0
# 38352             0.625605              -0.000000   235.47            -0.0
#
#        Sub_metering_2  Sub_metering_3  Year  Month  Day  Hours  Minute  \
# 23990       -0.000000       -0.000000  2007      4   27      6      12
# 8729        -0.000000        0.598538  2009      4   23     12      33
# 3451         0.356905        1.675643  2010      9   18     20      42
# 2628        -0.000000       -0.000000  2008      2   10      4      28
# 38352       -0.000000        1.646295  2008     12    2      9      58
#
#        Total_metering
# 23990       -0.000000
# 8729         0.632205
# 3451         2.076484
# 2628        -0.000000
# 38352        2.007244

# %%
X_train.shape
# Out:
# (33500, 12)

# %%
y_train.shape
# Out:
# (33500,)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model = DecisionTreeRegressor()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
from sklearn import tree

# %%
fig = plt.figure(figsize=(20,6))

# %%
tree.plot_tree(model,filled=True)
# Out:
# [Text(0.45800109611166523, 0.9833333333333333, 'X[0] <= 0.629\nsquared_error = 90.546\nsamples = 33500\nvalue = 9.314'),
#  Text(0.1898135159859659, 0.95, 'X[0] <= 0.307\nsquared_error = 22.467\nsamples = 27265\nvalue = 6.316'),
#  Text(0.04526725450325768, 0.9166666666666666, 'X[0] <= 0.211\nsquared_error = 2.074\nsamples = 14484\nvalue = 4.073'),
#  Text(0.01904303112890176, 0.8833333333333333, 'X[0] <= 0.16\nsquared_error = 0.963\nsamples = 6115\nvalue = 2.91'),
#  Text(0.009705691351190223, 0.85, 'X[11] <= 0.316\nsquared_error = 0.515\nsamples = 1812\nvalue = 1.885'),
#  Text(0.005155325128816591, 0.8166666666666667, 'X[0] <= 0.12\nsquared_error = 0.263\nsamples = 962\nvalue = 2.315'),
#  Text(0.002360218030064302, 0.7833333333333333, 'X[0] <= 0.096\nsquared_error = 0.074\nsamples = 445\nvalue = 1.845'),
#  Text(0.0009879487288676915, 0.75, 'X[0] <= 0.085\nsquared_error = 0.031\nsamples = 164\nvalue = 1.557'),
#  Text(0.0005450751607545885, 0.7166666666666667, 'X[0] <= 0.077\nsquared_error = 0.001\nsamples = 71\nvalue = 1.359'),
#  Text(0.00027253758037729423, 0.6833333333333333, 'X[0] <= 0.075\nsquared_error = 0.0\nsamples = 59\nvalue = 1.346'),
#  Text(0.00013626879018864712, 0.65, 'X[0] <= 0.073\nsquared_error = 0.0\nsamples = 30\nvalue = 1.327'),
#  Text(6.813439509432356e-05, 0.6166666666666667, 'squared_error = 0.0\nsamples = 6\nvalue = 1.3'),
#  Text(0.00020440318528297066, 0.6166666666666667, 'squared_error = -0.0\nsamples = 24\nvalue = 1.333'),
#  Text(0.0004088063705659413, 0.65, 'X[8] <= 24.5\nsquared_error = 0.0\nsamples = 29\nvalue = 1.367'),
#  Text(0.0003406719754716178, 0.6166666666666667, 'squared_error = -0.0\nsamples = 22\nvalue = 1.367'),
#  Text(0.00047694076566026487, 0.6166666666666667, 'squared_error = -0.0\nsamples = 7\nvalue = 1.367'),
#  Text(0.0008176127411318826, 0.6833333333333333, 'X[0] <= 0.08\nsquared_error = 0.001\nsamples = 12\nvalue = 1.422'),
#  Text(0.0006813439509432356, 0.65, 'X[0] <= 0.078\nsquared_error = 0.0\nsamples = 10\nvalue = 1.41'),
#  Text(0.000613209555848912, 0.6166666666666667, 'squared_error = -0.0\nsamples = 7\nvalue = 1.4'),
#  Text(0.0007494783460375591, 0.6166666666666667, 'squared_error = -0.0\nsamples = 3\nvalue = 1.433'),
#  Text(0.0009538815313205297, 0.65, 'X[2] <= 238.945\nsquared_error = 0.0\nsamples = 2\nvalue = 1.483'),
#  Text(0.0008857471362262062, 0.6166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 1.5'),
#  Text(0.0010220159264148533, 0.6166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 1.467'),
#  Text(0.0014308222969807946, 0.7166666666666667, 'X[0] <= 0.093\nsquared_error = 0.002\nsamples = 93\nvalue = 1.708'),
#  Text(0.0012945535067921475, 0.6833333333333333, 'X[0] <= 0.092\nsquared_error = 0.001\nsamples = 53\nvalue = 1.68'),
#  Text(0.001226419111697824, 0.65, 'X[0] <= 0.09\nsquared_error = 0.0\nsamples = 24\nvalue = 1.656'),
#  Text(0.0011582847166035004, 0.6166666666666667, 'X[6] <= 2007.5\nsquared_error = 0.0\nsamples = 6\nvalue = 1.622'),
#  Text(0.0010220159264148533, 0.5833333333333334, 'X[2] <= 240.395\nsquared_error = 0.0\nsamples = 4\nvalue = 1.633'),
#  Text(0.0009538815313205297, 0.55, 'squared_error = -0.0\nsamples = 3\nvalue = 1.633'),
#  Text(0.001090150321509177, 0.55, 'squared_error = 0.0\nsamples = 1\nvalue = 1.633'),
#  Text(0.0012945535067921475, 0.5833333333333334, 'X[10] <= 38.0\nsquared_error = 0.0\nsamples = 2\nvalue = 1.6'),
#  Text(0.001226419111697824, 0.55, 'squared_error = 0.0\nsamples = 1\nvalue = 1.6'),
#  Text(0.0013626879018864711, 0.55, 'squared_error = 0.0\nsamples = 1\nvalue = 1.6'),
#  Text(0.0012945535067921475, 0.6166666666666667, 'squared_error = 0.0\nsamples = 18\nvalue = 1.667'),
#  Text(0.0013626879018864711, 0.65, 'squared_error = -0.0\nsamples = 29\nvalue = 1.7'),
#  Text(0.0015670910871694416, 0.6833333333333333, 'X[0] <= 0.095\nsquared_error = 0.0\nsamples = 40\nvalue = 1.745'),
#  Text(0.0014989566920751182, 0.65, 'squared_error = -0.0\nsamples = 26\nvalue = 1.733'),
#  Text(0.0016352254822637653, 0.65, 'X[8] <= 8.5\nsquared_error = 0.0\nsamples = 14\nvalue = 1.767'),
#  Text(0.0015670910871694416, 0.6166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 1.767'),
#  Text(0.0017033598773580887, 0.6166666666666667, 'squared_error = 0.0\nsamples = 13\nvalue = 1.767'),
#  Text(0.003732487331260912, 0.75, 'X[0] <= 0.108\nsquared_error = 0.023\nsamples = 281\nvalue = 2.013'),
#  Text(0.0029255205893625176, 0.7166666666666667, 'X[0] <= 0.101\nsquared_error = 0.004\nsamples = 140\nvalue = 1.881'),
#  Text(0.002376187028914534, 0.6833333333333333, 'X[0] <= 0.1\nsquared_error = 0.001\nsamples = 81\nvalue = 1.835'),
#  Text(0.001975897457735383, 0.65, 'X[0] <= 0.098\nsquared_error = 0.0\nsamples = 54\nvalue = 1.82'),
#  Text(0.001839628667546736, 0.6166666666666667, 'X[10] <= 0.5\nsquared_error = 0.0\nsamples = 22\nvalue = 1.8'),
#  Text(0.0017714942724524124, 0.5833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 1.8'),
#  Text(0.0019077630626410595, 0.5833333333333334, 'X[10] <= 10.0\nsquared_error = 0.0\nsamples = 21\nvalue = 1.8'),
#  Text(0.001839628667546736, 0.55, 'squared_error = 0.0\nsamples = 3\nvalue = 1.8'),
#  Text(0.001975897457735383, 0.55, 'X[2] <= 235.165\nsquared_error = 0.0\nsamples = 18\nvalue = 1.8'),
#  Text(0.0019077630626410595, 0.5166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 1.8'),
#  Text(0.0020440318528297066, 0.5166666666666667, 'X[8] <= 11.0\nsquared_error = 0.0\nsamples = 17\nvalue = 1.8'),
#  Text(0.001975897457735383, 0.48333333333333334, 'squared_error = 0.0\nsamples = 3\nvalue = 1.8'),
#  Text(0.0021121662479240302, 0.48333333333333334, 'squared_error = -0.0\nsamples = 14\nvalue = 1.8'),
#  Text(0.0021121662479240302, 0.6166666666666667, 'X[9] <= 3.5\nsquared_error = 0.0\nsamples = 32\nvalue = 1.833'),
#  Text(0.0020440318528297066, 0.5833333333333334, 'squared_error = 0.0\nsamples = 6\nvalue = 1.833'),
#  Text(0.002180300643018354, 0.5833333333333334, 'squared_error = -0.0\nsamples = 26\nvalue = 1.833'),
#  Text(0.0027764766000936848, 0.65, 'X[7] <= 10.5\nsquared_error = 0.0\nsamples = 27\nvalue = 1.867'),
#  Text(0.002555039816037133, 0.6166666666666667, 'X[7] <= 7.5\nsquared_error = 0.0\nsamples = 25\nvalue = 1.867'),
#  Text(0.0023165694332070007, 0.5833333333333334, 'X[8] <= 6.0\nsquared_error = 0.0\nsamples = 10\nvalue = 1.867'),
#  Text(0.002248435038112677, 0.55, 'squared_error = 0.0\nsamples = 3\nvalue = 1.867'),
#  Text(0.0023847038283013244, 0.55, 'X[2] <= 236.03\nsquared_error = 0.0\nsamples = 7\nvalue = 1.867'),
#  Text(0.0023165694332070007, 0.5166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 1.867'),
#  Text(0.002452838223395648, 0.5166666666666667, 'squared_error = 0.0\nsamples = 6\nvalue = 1.867'),
#  Text(0.002793510198867266, 0.5833333333333334, 'X[9] <= 3.5\nsquared_error = 0.0\nsamples = 15\nvalue = 1.867'),
#  Text(0.0026572414086786186, 0.55, 'X[10] <= 20.0\nsquared_error = 0.0\nsamples = 5\nvalue = 1.867'),
#  Text(0.002589107013584295, 0.5166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 1.867'),
#  Text(0.0027253758037729422, 0.5166666666666667, 'X[9] <= 0.5\nsquared_error = 0.0\nsamples = 4\nvalue = 1.867'),
#  Text(0.0026572414086786186, 0.48333333333333334, 'squared_error = 0.0\nsamples = 2\nvalue = 1.867'),
#  Text(0.002793510198867266, 0.48333333333333334, 'squared_error = 0.0\nsamples = 2\nvalue = 1.867'),
#  Text(0.0029297789890559128, 0.55, 'X[2] <= 239.265\nsquared_error = 0.0\nsamples = 10\nvalue = 1.867'),
#  Text(0.002861644593961589, 0.5166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 1.867'),
#  Text(0.0029979133841502364, 0.5166666666666667, 'X[9] <= 4.5\nsquared_error = 0.0\nsamples = 9\nvalue = 1.867'),
#  Text(0.0029297789890559128, 0.48333333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 1.867'),
#  Text(0.00306604777924456, 0.48333333333333334, 'X[9] <= 10.0\nsquared_error = 0.0\nsamples = 8\nvalue = 1.867'),
#  Text(0.0029979133841502364, 0.45, 'squared_error = 0.0\nsamples = 4\nvalue = 1.867'),
#  Text(0.0031341821743388833, 0.45, 'squared_error = 0.0\nsamples = 4\nvalue = 1.867'),
#  Text(0.0029979133841502364, 0.6166666666666667, 'X[8] <= 5.5\nsquared_error = 0.0\nsamples = 2\nvalue = 1.867'),
#  Text(0.0029297789890559128, 0.5833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 1.867'),
#  Text(0.00306604777924456, 0.5833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 1.867'),
#  Text(0.003474854149810501, 0.6833333333333333, 'X[0] <= 0.105\nsquared_error = 0.002\nsamples = 59\nvalue = 1.944'),
#  Text(0.0033385853596218542, 0.65, 'X[0] <= 0.103\nsquared_error = 0.0\nsamples = 33\nvalue = 1.91'),
#  Text(0.0032704509645275306, 0.6166666666666667, 'X[2] <= 236.075\nsquared_error = 0.0\nsamples = 23\nvalue = 1.9'),
#  Text(0.003202316569433207, 0.5833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 1.9'),
#  Text(0.0033385853596218542, 0.5833333333333334, 'X[7] <= 4.5\nsquared_error = 0.0\nsamples = 22\nvalue = 1.9'),
#  Text(0.0032704509645275306, 0.55, 'squared_error = 0.0\nsamples = 2\nvalue = 1.9'),
#  Text(0.0034067197547161775, 0.55, 'X[2] <= 236.525\nsquared_error = 0.0\nsamples = 20\nvalue = 1.9'),
#  Text(0.0033385853596218542, 0.5166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 1.9'),
#  Text(0.003474854149810501, 0.5166666666666667, 'X[9] <= 0.5\nsquared_error = 0.0\nsamples = 19\nvalue = 1.9'),
#  Text(0.0034067197547161775, 0.48333333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 1.9'),
#  Text(0.0035429885449048248, 0.48333333333333334, 'X[8] <= 5.5\nsquared_error = 0.0\nsamples = 18\nvalue = 1.9'),
#  Text(0.0034067197547161775, 0.45, 'X[10] <= 5.5\nsquared_error = 0.0\nsamples = 3\nvalue = 1.9'),
#  Text(0.0033385853596218542, 0.4166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 1.9'),
#  Text(0.003474854149810501, 0.4166666666666667, 'X[2] <= 237.165\nsquared_error = 0.0\nsamples = 2\nvalue = 1.9'),
#  Text(0.0034067197547161775, 0.38333333333333336, 'squared_error = 0.0\nsamples = 1\nvalue = 1.9'),
#  Text(0.0035429885449048248, 0.38333333333333336, 'squared_error = 0.0\nsamples = 1\nvalue = 1.9'),
#  Text(0.003679257335093472, 0.45, 'X[2] <= 237.445\nsquared_error = 0.0\nsamples = 15\nvalue = 1.9'),
#  Text(0.0036111229399991484, 0.4166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 1.9'),
#  Text(0.0037473917301877953, 0.4166666666666667, 'X[9] <= 3.5\nsquared_error = 0.0\nsamples = 14\nvalue = 1.9'),
#  Text(0.003679257335093472, 0.38333333333333336, 'squared_error = 0.0\nsamples = 1\nvalue = 1.9'),
#  Text(0.003815526125282119, 0.38333333333333336, 'X[2] <= 237.995\nsquared_error = 0.0\nsamples = 13\nvalue = 1.9'),
#  Text(0.0037473917301877953, 0.35, 'squared_error = 0.0\nsamples = 1\nvalue = 1.9'),
#  Text(0.0038836605203764426, 0.35, 'X[2] <= 238.555\nsquared_error = 0.0\nsamples = 12\nvalue = 1.9'),
#  Text(0.003815526125282119, 0.31666666666666665, 'squared_error = 0.0\nsamples = 1\nvalue = 1.9'),
#  Text(0.003951794915470766, 0.31666666666666665, 'squared_error = 0.0\nsamples = 11\nvalue = 1.9'),
#  Text(0.0034067197547161775, 0.6166666666666667, 'squared_error = -0.0\nsamples = 10\nvalue = 1.933'),
#  Text(0.0036111229399991484, 0.65, 'X[0] <= 0.106\nsquared_error = 0.0\nsamples = 26\nvalue = 1.986'),
#  Text(0.0035429885449048248, 0.6166666666666667, 'squared_error = -0.0\nsamples = 11\nvalue = 1.967'),
#  Text(0.003679257335093472, 0.6166666666666667, 'squared_error = -0.0\nsamples = 15\nvalue = 2.0'),
#  Text(0.004539454073159307, 0.7166666666666667, 'X[0] <= 0.114\nsquared_error = 0.007\nsamples = 141\nvalue = 2.144'),
#  Text(0.0041732316995273175, 0.6833333333333333, 'X[0] <= 0.111\nsquared_error = 0.001\nsamples = 74\nvalue = 2.074'),
#  Text(0.003985862113017928, 0.65, 'X[0] <= 0.109\nsquared_error = 0.0\nsamples = 47\nvalue = 2.048'),
#  Text(0.003815526125282119, 0.6166666666666667, 'X[7] <= 7.5\nsquared_error = 0.0\nsamples = 26\nvalue = 2.033'),
#  Text(0.003679257335093472, 0.5833333333333334, 'X[10] <= 8.0\nsquared_error = 0.0\nsamples = 17\nvalue = 2.033'),
#  Text(0.0036111229399991484, 0.55, 'squared_error = 0.0\nsamples = 5\nvalue = 2.033'),
#  Text(0.0037473917301877953, 0.55, 'X[10] <= 10.5\nsquared_error = 0.0\nsamples = 12\nvalue = 2.033'),
#  Text(0.003679257335093472, 0.5166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 2.033'),
#  Text(0.003815526125282119, 0.5166666666666667, 'X[8] <= 7.0\nsquared_error = 0.0\nsamples = 11\nvalue = 2.033'),
#  Text(0.0037473917301877953, 0.48333333333333334, 'squared_error = 0.0\nsamples = 2\nvalue = 2.033'),
#  Text(0.0038836605203764426, 0.48333333333333334, 'X[7] <= 4.5\nsquared_error = 0.0\nsamples = 9\nvalue = 2.033'),
#  Text(0.003815526125282119, 0.45, 'squared_error = 0.0\nsamples = 1\nvalue = 2.033'),
#  Text(0.003951794915470766, 0.45, 'squared_error = 0.0\nsamples = 8\nvalue = 2.033'),
#  Text(0.003951794915470766, 0.5833333333333334, 'X[8] <= 15.5\nsquared_error = 0.0\nsamples = 9\nvalue = 2.033'),
#  Text(0.0038836605203764426, 0.55, 'squared_error = 0.0\nsamples = 8\nvalue = 2.033'),
#  Text(0.0040199293105650895, 0.55, 'squared_error = 0.0\nsamples = 1\nvalue = 2.033'),
#  Text(0.004156198100753737, 0.6166666666666667, 'X[10] <= 13.5\nsquared_error = 0.0\nsamples = 21\nvalue = 2.067'),
#  Text(0.004088063705659413, 0.5833333333333334, 'squared_error = 0.0\nsamples = 4\nvalue = 2.067'),
#  Text(0.0042243324958480604, 0.5833333333333334, 'squared_error = -0.0\nsamples = 17\nvalue = 2.067'),
#  Text(0.004360601286036708, 0.65, 'X[0] <= 0.112\nsquared_error = 0.0\nsamples = 27\nvalue = 2.119'),
#  Text(0.004292466890942384, 0.6166666666666667, 'squared_error = -0.0\nsamples = 12\nvalue = 2.1'),
#  Text(0.0044287356811310305, 0.6166666666666667, 'X[8] <= 6.5\nsquared_error = 0.0\nsamples = 15\nvalue = 2.133'),
#  Text(0.004360601286036708, 0.5833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 2.133'),
#  Text(0.004496870076225354, 0.5833333333333334, 'X[10] <= 6.5\nsquared_error = 0.0\nsamples = 14\nvalue = 2.133'),
#  Text(0.0044287356811310305, 0.55, 'squared_error = 0.0\nsamples = 1\nvalue = 2.133'),
#  Text(0.004565004471319678, 0.55, 'X[8] <= 24.0\nsquared_error = 0.0\nsamples = 13\nvalue = 2.133'),
#  Text(0.0044287356811310305, 0.5166666666666667, 'X[9] <= 3.0\nsquared_error = 0.0\nsamples = 9\nvalue = 2.133'),
#  Text(0.004360601286036708, 0.48333333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 2.133'),
#  Text(0.004496870076225354, 0.48333333333333334, 'X[9] <= 7.5\nsquared_error = 0.0\nsamples = 8\nvalue = 2.133'),
#  Text(0.0044287356811310305, 0.45, 'squared_error = 0.0\nsamples = 1\nvalue = 2.133'),
#  Text(0.004565004471319678, 0.45, 'X[2] <= 238.115\nsquared_error = 0.0\nsamples = 7\nvalue = 2.133'),
#  Text(0.004496870076225354, 0.4166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 2.133'),
#  Text(0.0046331388664140015, 0.4166666666666667, 'X[10] <= 12.0\nsquared_error = 0.0\nsamples = 6\nvalue = 2.133'),
#  Text(0.004565004471319678, 0.38333333333333336, 'squared_error = 0.0\nsamples = 1\nvalue = 2.133'),
#  Text(0.004701273261508325, 0.38333333333333336, 'squared_error = 0.0\nsamples = 5\nvalue = 2.133'),
#  Text(0.004701273261508325, 0.5166666666666667, 'X[9] <= 3.0\nsquared_error = 0.0\nsamples = 4\nvalue = 2.133'),
#  Text(0.0046331388664140015, 0.48333333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 2.133'),
#  Text(0.004769407656602649, 0.48333333333333334, 'squared_error = 0.0\nsamples = 3\nvalue = 2.133'),
#  Text(0.004905676446791296, 0.6833333333333333, 'X[0] <= 0.117\nsquared_error = 0.002\nsamples = 67\nvalue = 2.222'),
#  Text(0.004769407656602649, 0.65, 'X[0] <= 0.116\nsquared_error = 0.0\nsamples = 33\nvalue = 2.182'),
#  Text(0.004701273261508325, 0.6166666666666667, 'X[8] <= 6.0\nsquared_error = 0.0\nsamples = 18\nvalue = 2.167'),
#  Text(0.0046331388664140015, 0.5833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 2.167'),
#  Text(0.004769407656602649, 0.5833333333333334, 'squared_error = -0.0\nsamples = 17\nvalue = 2.167'),
#  Text(0.0048375420516969725, 0.6166666666666667, 'squared_error = -0.0\nsamples = 15\nvalue = 2.2'),
#  Text(0.0050419452369799425, 0.65, 'X[0] <= 0.119\nsquared_error = 0.0\nsamples = 34\nvalue = 2.261'),
#  Text(0.00497381084188562, 0.6166666666666667, 'squared_error = 0.0\nsamples = 6\nvalue = 2.233'),
#  Text(0.005110079632074266, 0.6166666666666667, 'X[9] <= 1.0\nsquared_error = 0.0\nsamples = 28\nvalue = 2.267'),
#  Text(0.0050419452369799425, 0.5833333333333334, 'squared_error = 0.0\nsamples = 2\nvalue = 2.267'),
#  Text(0.00517821402716859, 0.5833333333333334, 'X[9] <= 3.0\nsquared_error = 0.0\nsamples = 26\nvalue = 2.267'),
#  Text(0.005110079632074266, 0.55, 'squared_error = 0.0\nsamples = 1\nvalue = 2.267'),
#  Text(0.0052463484222629135, 0.55, 'X[10] <= 3.5\nsquared_error = 0.0\nsamples = 25\nvalue = 2.267'),
#  Text(0.00517821402716859, 0.5166666666666667, 'squared_error = 0.0\nsamples = 2\nvalue = 2.267'),
#  Text(0.005314482817357237, 0.5166666666666667, 'X[2] <= 238.19\nsquared_error = 0.0\nsamples = 23\nvalue = 2.267'),
#  Text(0.0052463484222629135, 0.48333333333333334, 'squared_error = 0.0\nsamples = 3\nvalue = 2.267'),
#  Text(0.005382617212451561, 0.48333333333333334, 'X[10] <= 5.0\nsquared_error = 0.0\nsamples = 20\nvalue = 2.267'),
#  Text(0.005314482817357237, 0.45, 'squared_error = 0.0\nsamples = 1\nvalue = 2.267'),
#  Text(0.0054507516075458845, 0.45, 'X[2] <= 238.725\nsquared_error = 0.0\nsamples = 19\nvalue = 2.267'),
#  Text(0.005382617212451561, 0.4166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 2.267'),
#  Text(0.005518886002640208, 0.4166666666666667, 'X[9] <= 5.5\nsquared_error = 0.0\nsamples = 18\nvalue = 2.267'),
#  Text(0.0054507516075458845, 0.38333333333333336, 'squared_error = 0.0\nsamples = 3\nvalue = 2.267'),
#  Text(0.005587020397734532, 0.38333333333333336, 'X[9] <= 8.5\nsquared_error = 0.0\nsamples = 15\nvalue = 2.267'),
#  Text(0.005518886002640208, 0.35, 'squared_error = 0.0\nsamples = 1\nvalue = 2.267'),
#  Text(0.0056551547928288546, 0.35, 'X[2] <= 239.15\nsquared_error = 0.0\nsamples = 14\nvalue = 2.267'),
#  Text(0.005587020397734532, 0.31666666666666665, 'squared_error = 0.0\nsamples = 1\nvalue = 2.267'),
#  Text(0.005723289187923178, 0.31666666666666665, 'X[2] <= 240.525\nsquared_error = 0.0\nsamples = 13\nvalue = 2.267'),
#  Text(0.0056551547928288546, 0.2833333333333333, 'squared_error = 0.0\nsamples = 4\nvalue = 2.267'),
#  Text(0.005791423583017502, 0.2833333333333333, 'X[8] <= 7.5\nsquared_error = 0.0\nsamples = 9\nvalue = 2.267'),
#  Text(0.005723289187923178, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 2.267'),
#  Text(0.0058595579781118255, 0.25, 'squared_error = -0.0\nsamples = 8\nvalue = 2.267'),
#  Text(0.007950432227568879, 0.7833333333333333, 'X[0] <= 0.141\nsquared_error = 0.07\nsamples = 517\nvalue = 2.721'),
#  Text(0.006387599540092833, 0.75, 'X[0] <= 0.129\nsquared_error = 0.016\nsamples = 280\nvalue = 2.505'),
#  Text(0.005893625175658988, 0.7166666666666667, 'X[0] <= 0.125\nsquared_error = 0.004\nsamples = 113\nvalue = 2.371'),
#  Text(0.005587020397734532, 0.6833333333333333, 'X[0] <= 0.122\nsquared_error = 0.001\nsamples = 64\nvalue = 2.324'),
#  Text(0.0054507516075458845, 0.65, 'X[7] <= 1.5\nsquared_error = 0.0\nsamples = 31\nvalue = 2.3'),
#  Text(0.005382617212451561, 0.6166666666666667, 'squared_error = 0.0\nsamples = 2\nvalue = 2.3'),
#  Text(0.005518886002640208, 0.6166666666666667, 'X[1] <= 0.022\nsquared_error = 0.0\nsamples = 29\nvalue = 2.3'),
#  Text(0.0054507516075458845, 0.5833333333333334, 'X[6] <= 2007.5\nsquared_error = 0.0\nsamples = 28\nvalue = 2.3'),
#  Text(0.005382617212451561, 0.55, 'squared_error = -0.0\nsamples = 9\nvalue = 2.3'),
#  Text(0.005518886002640208, 0.55, 'X[10] <= 1.5\nsquared_error = 0.0\nsamples = 19\nvalue = 2.3'),
#  Text(0.0054507516075458845, 0.5166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 2.3'),
#  Text(0.005587020397734532, 0.5166666666666667, 'X[7] <= 2.5\nsquared_error = 0.0\nsamples = 18\nvalue = 2.3'),
#  Text(0.005518886002640208, 0.48333333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 2.3'),
#  Text(0.0056551547928288546, 0.48333333333333334, 'X[2] <= 239.14\nsquared_error = 0.0\nsamples = 17\nvalue = 2.3'),
#  Text(0.005587020397734532, 0.45, 'squared_error = 0.0\nsamples = 1\nvalue = 2.3'),
#  Text(0.005723289187923178, 0.45, 'X[2] <= 239.71\nsquared_error = 0.0\nsamples = 16\nvalue = 2.3'),
#  Text(0.0056551547928288546, 0.4166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 2.3'),
#  Text(0.005791423583017502, 0.4166666666666667, 'X[9] <= 1.5\nsquared_error = 0.0\nsamples = 15\nvalue = 2.3'),
#  Text(0.005723289187923178, 0.38333333333333336, 'squared_error = 0.0\nsamples = 1\nvalue = 2.3'),
#  Text(0.0058595579781118255, 0.38333333333333336, 'squared_error = -0.0\nsamples = 14\nvalue = 2.3'),
#  Text(0.005587020397734532, 0.5833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 2.3'),
#  Text(0.005723289187923178, 0.65, 'X[0] <= 0.123\nsquared_error = 0.0\nsamples = 33\nvalue = 2.346'),
#  Text(0.0056551547928288546, 0.6166666666666667, 'squared_error = -0.0\nsamples = 20\nvalue = 2.333'),
#  Text(0.005791423583017502, 0.6166666666666667, 'X[8] <= 7.5\nsquared_error = 0.0\nsamples = 13\nvalue = 2.367'),
#  Text(0.005723289187923178, 0.5833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 2.367'),
#  Text(0.0058595579781118255, 0.5833333333333334, 'squared_error = -0.0\nsamples = 12\nvalue = 2.367'),
#  Text(0.006200229953583443, 0.6833333333333333, 'X[0] <= 0.128\nsquared_error = 0.001\nsamples = 49\nvalue = 2.433'),
#  Text(0.00613209555848912, 0.65, 'X[0] <= 0.126\nsquared_error = 0.0\nsamples = 34\nvalue = 2.419'),
#  Text(0.0060639611633947965, 0.6166666666666667, 'X[10] <= 9.0\nsquared_error = 0.0\nsamples = 15\nvalue = 2.4'),
#  Text(0.005995826768300473, 0.5833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 2.4'),
#  Text(0.00613209555848912, 0.5833333333333334, 'X[8] <= 7.5\nsquared_error = 0.0\nsamples = 14\nvalue = 2.4'),
#  Text(0.0060639611633947965, 0.55, 'squared_error = 0.0\nsamples = 1\nvalue = 2.4'),
#  Text(0.006200229953583443, 0.55, 'X[7] <= 5.5\nsquared_error = 0.0\nsamples = 13\nvalue = 2.4'),
#  Text(0.00613209555848912, 0.5166666666666667, 'squared_error = 0.0\nsamples = 2\nvalue = 2.4'),
#  Text(0.006268364348677767, 0.5166666666666667, 'X[2] <= 236.075\nsquared_error = 0.0\nsamples = 11\nvalue = 2.4'),
#  Text(0.006200229953583443, 0.48333333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 2.4'),
#  Text(0.00633649874377209, 0.48333333333333334, 'X[10] <= 16.0\nsquared_error = 0.0\nsamples = 10\nvalue = 2.4'),
#  Text(0.006268364348677767, 0.45, 'squared_error = 0.0\nsamples = 1\nvalue = 2.4'),
#  Text(0.006404633138866414, 0.45, 'squared_error = -0.0\nsamples = 9\nvalue = 2.4'),
#  Text(0.006200229953583443, 0.6166666666666667, 'squared_error = -0.0\nsamples = 19\nvalue = 2.433'),
#  Text(0.006268364348677767, 0.65, 'squared_error = -0.0\nsamples = 15\nvalue = 2.467'),
#  Text(0.006881573904526679, 0.7166666666666667, 'X[0] <= 0.135\nsquared_error = 0.004\nsamples = 167\nvalue = 2.595'),
#  Text(0.006540901929055061, 0.6833333333333333, 'X[0] <= 0.132\nsquared_error = 0.001\nsamples = 107\nvalue = 2.554'),
#  Text(0.006404633138866414, 0.65, 'X[0] <= 0.131\nsquared_error = 0.0\nsamples = 48\nvalue = 2.516'),
#  Text(0.00633649874377209, 0.6166666666666667, 'squared_error = -0.0\nsamples = 25\nvalue = 2.5'),
#  Text(0.0064727675339607375, 0.6166666666666667, 'X[8] <= 8.5\nsquared_error = 0.0\nsamples = 23\nvalue = 2.533'),
#  Text(0.006404633138866414, 0.5833333333333334, 'squared_error = 0.0\nsamples = 5\nvalue = 2.533'),
#  Text(0.006540901929055061, 0.5833333333333334, 'X[2] <= 238.88\nsquared_error = 0.0\nsamples = 18\nvalue = 2.533'),
#  Text(0.0064727675339607375, 0.55, 'squared_error = 0.0\nsamples = 4\nvalue = 2.533'),
#  Text(0.006609036324149385, 0.55, 'X[9] <= 1.5\nsquared_error = 0.0\nsamples = 14\nvalue = 2.533'),
#  Text(0.006540901929055061, 0.5166666666666667, 'squared_error = 0.0\nsamples = 4\nvalue = 2.533'),
#  Text(0.0066771707192437085, 0.5166666666666667, 'squared_error = -0.0\nsamples = 10\nvalue = 2.533'),
#  Text(0.0066771707192437085, 0.65, 'X[0] <= 0.134\nsquared_error = 0.0\nsamples = 59\nvalue = 2.585'),
#  Text(0.006609036324149385, 0.6166666666666667, 'squared_error = -0.0\nsamples = 27\nvalue = 2.567'),
#  Text(0.006745305114338032, 0.6166666666666667, 'X[10] <= 20.0\nsquared_error = 0.0\nsamples = 32\nvalue = 2.6'),
#  Text(0.0066771707192437085, 0.5833333333333334, 'squared_error = -0.0\nsamples = 12\nvalue = 2.6'),
#  Text(0.006813439509432355, 0.5833333333333334, 'X[9] <= 6.5\nsquared_error = 0.0\nsamples = 20\nvalue = 2.6'),
#  Text(0.006745305114338032, 0.55, 'squared_error = 0.0\nsamples = 3\nvalue = 2.6'),
#  Text(0.006881573904526679, 0.55, 'squared_error = -0.0\nsamples = 17\nvalue = 2.6'),
#  Text(0.007222245879998297, 0.6833333333333333, 'X[0] <= 0.138\nsquared_error = 0.001\nsamples = 60\nvalue = 2.669'),
#  Text(0.0070859770898096495, 0.65, 'X[0] <= 0.137\nsquared_error = 0.0\nsamples = 42\nvalue = 2.649'),
#  Text(0.007017842694715326, 0.6166666666666667, 'X[10] <= 8.5\nsquared_error = 0.0\nsamples = 22\nvalue = 2.633'),
#  Text(0.006949708299621002, 0.5833333333333334, 'squared_error = 0.0\nsamples = 5\nvalue = 2.633'),
#  Text(0.0070859770898096495, 0.5833333333333334, 'X[2] <= 240.48\nsquared_error = 0.0\nsamples = 17\nvalue = 2.633'),
#  Text(0.007017842694715326, 0.55, 'squared_error = 0.0\nsamples = 4\nvalue = 2.633'),
#  Text(0.007154111484903973, 0.55, 'X[2] <= 240.705\nsquared_error = 0.0\nsamples = 13\nvalue = 2.633'),
#  Text(0.0070859770898096495, 0.5166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 2.633'),
#  Text(0.007222245879998297, 0.5166666666666667, 'X[7] <= 4.5\nsquared_error = 0.0\nsamples = 12\nvalue = 2.633'),
#  Text(0.007154111484903973, 0.48333333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 2.633'),
#  Text(0.0072903802750926205, 0.48333333333333334, 'X[10] <= 11.5\nsquared_error = 0.0\nsamples = 11\nvalue = 2.633'),
#  Text(0.007222245879998297, 0.45, 'squared_error = 0.0\nsamples = 1\nvalue = 2.633'),
#  Text(0.007358514670186944, 0.45, 'X[9] <= 1.5\nsquared_error = 0.0\nsamples = 10\nvalue = 2.633'),
#  Text(0.0072903802750926205, 0.4166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 2.633'),
#  Text(0.007426649065281267, 0.4166666666666667, 'X[6] <= 2009.5\nsquared_error = 0.0\nsamples = 9\nvalue = 2.633'),
#  Text(0.007358514670186944, 0.38333333333333336, 'squared_error = 0.0\nsamples = 4\nvalue = 2.633'),
#  Text(0.007494783460375591, 0.38333333333333336, 'X[9] <= 4.5\nsquared_error = 0.0\nsamples = 5\nvalue = 2.633'),
#  Text(0.007426649065281267, 0.35, 'squared_error = 0.0\nsamples = 1\nvalue = 2.633'),
#  Text(0.007562917855469914, 0.35, 'squared_error = 0.0\nsamples = 4\nvalue = 2.633'),
#  Text(0.007154111484903973, 0.6166666666666667, 'squared_error = -0.0\nsamples = 20\nvalue = 2.667'),
#  Text(0.007358514670186944, 0.65, 'X[0] <= 0.14\nsquared_error = 0.0\nsamples = 18\nvalue = 2.717'),
#  Text(0.0072903802750926205, 0.6166666666666667, 'X[8] <= 6.5\nsquared_error = 0.0\nsamples = 9\nvalue = 2.7'),
#  Text(0.007222245879998297, 0.5833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 2.7'),
#  Text(0.007358514670186944, 0.5833333333333334, 'X[7] <= 5.5\nsquared_error = 0.0\nsamples = 8\nvalue = 2.7'),
#  Text(0.0072903802750926205, 0.55, 'squared_error = 0.0\nsamples = 4\nvalue = 2.7'),
#  Text(0.007426649065281267, 0.55, 'X[2] <= 240.12\nsquared_error = 0.0\nsamples = 4\nvalue = 2.7'),
#  Text(0.007358514670186944, 0.5166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 2.7'),
#  Text(0.007494783460375591, 0.5166666666666667, 'squared_error = -0.0\nsamples = 3\nvalue = 2.7'),
#  Text(0.007426649065281267, 0.6166666666666667, 'squared_error = -0.0\nsamples = 9\nvalue = 2.733'),
#  Text(0.009513264915044926, 0.75, 'X[0] <= 0.151\nsquared_error = 0.014\nsamples = 237\nvalue = 2.975'),
#  Text(0.008738236170846996, 0.7166666666666667, 'X[0] <= 0.147\nsquared_error = 0.004\nsamples = 125\nvalue = 2.88'),
#  Text(0.008090959417450923, 0.6833333333333333, 'X[0] <= 0.144\nsquared_error = 0.001\nsamples = 58\nvalue = 2.82'),
#  Text(0.0076991866456585616, 0.65, 'X[0] <= 0.143\nsquared_error = 0.0\nsamples = 29\nvalue = 2.787'),
#  Text(0.007562917855469914, 0.6166666666666667, 'X[8] <= 5.5\nsquared_error = 0.0\nsamples = 11\nvalue = 2.767'),
#  Text(0.007494783460375591, 0.5833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 2.767'),
#  Text(0.007631052250564238, 0.5833333333333334, 'X[2] <= 237.44\nsquared_error = 0.0\nsamples = 10\nvalue = 2.767'),
#  Text(0.007562917855469914, 0.55, 'squared_error = 0.0\nsamples = 1\nvalue = 2.767'),
#  Text(0.0076991866456585616, 0.55, 'X[1] <= 0.053\nsquared_error = 0.0\nsamples = 9\nvalue = 2.767'),
#  Text(0.007631052250564238, 0.5166666666666667, 'squared_error = 0.0\nsamples = 6\nvalue = 2.767'),
#  Text(0.007767321040752885, 0.5166666666666667, 'X[1] <= 0.075\nsquared_error = 0.0\nsamples = 3\nvalue = 2.767'),
#  Text(0.0076991866456585616, 0.48333333333333334, 'X[9] <= 7.5\nsquared_error = 0.0\nsamples = 2\nvalue = 2.767'),
#  Text(0.007631052250564238, 0.45, 'squared_error = 0.0\nsamples = 1\nvalue = 2.767'),
#  Text(0.007767321040752885, 0.45, 'squared_error = 0.0\nsamples = 1\nvalue = 2.767'),
#  Text(0.007835455435847209, 0.48333333333333334, 'squared_error = -0.0\nsamples = 1\nvalue = 2.767'),
#  Text(0.007835455435847209, 0.6166666666666667, 'X[2] <= 235.74\nsquared_error = 0.0\nsamples = 18\nvalue = 2.8'),
#  Text(0.007767321040752885, 0.5833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 2.8'),
#  Text(0.007903589830941532, 0.5833333333333334, 'X[7] <= 2.0\nsquared_error = 0.0\nsamples = 17\nvalue = 2.8'),
#  Text(0.007835455435847209, 0.55, 'squared_error = 0.0\nsamples = 1\nvalue = 2.8'),
#  Text(0.007971724226035856, 0.55, 'X[2] <= 239.17\nsquared_error = 0.0\nsamples = 16\nvalue = 2.8'),
#  Text(0.007903589830941532, 0.5166666666666667, 'squared_error = 0.0\nsamples = 5\nvalue = 2.8'),
#  Text(0.008039858621130179, 0.5166666666666667, 'X[10] <= 12.5\nsquared_error = 0.0\nsamples = 11\nvalue = 2.8'),
#  Text(0.007971724226035856, 0.48333333333333334, 'squared_error = -0.0\nsamples = 3\nvalue = 2.8'),
#  Text(0.008107993016224503, 0.48333333333333334, 'squared_error = -0.0\nsamples = 8\nvalue = 2.8'),
#  Text(0.008482732189243282, 0.65, 'X[0] <= 0.146\nsquared_error = 0.0\nsamples = 29\nvalue = 2.852'),
#  Text(0.00841459779414896, 0.6166666666666667, 'squared_error = -0.0\nsamples = 13\nvalue = 2.833'),
#  Text(0.008550866584337605, 0.6166666666666667, 'X[10] <= 9.0\nsquared_error = 0.0\nsamples = 16\nvalue = 2.867'),
#  Text(0.008482732189243282, 0.5833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 2.867'),
#  Text(0.00861900097943193, 0.5833333333333334, 'X[7] <= 11.0\nsquared_error = 0.0\nsamples = 15\nvalue = 2.867'),
#  Text(0.008448664991696121, 0.55, 'X[1] <= 0.077\nsquared_error = 0.0\nsamples = 13\nvalue = 2.867'),
#  Text(0.008312396201507474, 0.5166666666666667, 'X[6] <= 2007.5\nsquared_error = 0.0\nsamples = 11\nvalue = 2.867'),
#  Text(0.00824426180641315, 0.48333333333333334, 'squared_error = 0.0\nsamples = 6\nvalue = 2.867'),
#  Text(0.008380530596601796, 0.48333333333333334, 'X[10] <= 37.0\nsquared_error = 0.0\nsamples = 5\nvalue = 2.867'),
#  Text(0.008312396201507474, 0.45, 'squared_error = 0.0\nsamples = 2\nvalue = 2.867'),
#  Text(0.008448664991696121, 0.45, 'squared_error = -0.0\nsamples = 3\nvalue = 2.867'),
#  Text(0.008584933781884768, 0.5166666666666667, 'X[10] <= 45.5\nsquared_error = 0.0\nsamples = 2\nvalue = 2.867'),
#  Text(0.008516799386790444, 0.48333333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 2.867'),
#  Text(0.008653068176979091, 0.48333333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 2.867'),
#  Text(0.008789336967167738, 0.55, 'X[8] <= 8.5\nsquared_error = 0.0\nsamples = 2\nvalue = 2.867'),
#  Text(0.008721202572073415, 0.5166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 2.867'),
#  Text(0.008857471362262061, 0.5166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 2.867'),
#  Text(0.00938551292424307, 0.6833333333333333, 'X[0] <= 0.149\nsquared_error = 0.001\nsamples = 67\nvalue = 2.932'),
#  Text(0.009164076140186517, 0.65, 'X[8] <= 15.5\nsquared_error = 0.0\nsamples = 24\nvalue = 2.9'),
#  Text(0.008925605757356386, 0.6166666666666667, 'X[9] <= 0.5\nsquared_error = 0.0\nsamples = 8\nvalue = 2.9'),
#  Text(0.008857471362262061, 0.5833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 2.9'),
#  Text(0.008993740152450708, 0.5833333333333334, 'X[2] <= 238.22\nsquared_error = 0.0\nsamples = 7\nvalue = 2.9'),
#  Text(0.008925605757356386, 0.55, 'squared_error = 0.0\nsamples = 1\nvalue = 2.9'),
#  Text(0.009061874547545033, 0.55, 'squared_error = -0.0\nsamples = 6\nvalue = 2.9'),
#  Text(0.00940254652301665, 0.6166666666666667, 'X[1] <= 0.021\nsquared_error = 0.0\nsamples = 16\nvalue = 2.9'),
#  Text(0.009266277732828003, 0.5833333333333334, 'X[9] <= 1.0\nsquared_error = 0.0\nsamples = 7\nvalue = 2.9'),
#  Text(0.00919814333773368, 0.55, 'squared_error = 0.0\nsamples = 1\nvalue = 2.9'),
#  Text(0.009334412127922328, 0.55, 'squared_error = -0.0\nsamples = 6\nvalue = 2.9'),
#  Text(0.009538815313205298, 0.5833333333333334, 'X[7] <= 6.5\nsquared_error = 0.0\nsamples = 9\nvalue = 2.9'),
#  Text(0.009470680918110973, 0.55, 'squared_error = 0.0\nsamples = 2\nvalue = 2.9'),
#  Text(0.00960694970829962, 0.55, 'X[7] <= 7.5\nsquared_error = 0.0\nsamples = 7\nvalue = 2.9'),
#  Text(0.009538815313205298, 0.5166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 2.9'),
#  Text(0.009675084103393945, 0.5166666666666667, 'squared_error = -0.0\nsamples = 6\nvalue = 2.9'),
#  Text(0.00960694970829962, 0.65, 'X[0] <= 0.15\nsquared_error = 0.0\nsamples = 43\nvalue = 2.95'),
#  Text(0.009538815313205298, 0.6166666666666667, 'squared_error = -0.0\nsamples = 22\nvalue = 2.933'),
#  Text(0.009675084103393945, 0.6166666666666667, 'squared_error = -0.0\nsamples = 21\nvalue = 2.967'),
#  Text(0.010288293659242857, 0.7166666666666667, 'X[0] <= 0.156\nsquared_error = 0.003\nsamples = 112\nvalue = 3.082'),
#  Text(0.010083890473959885, 0.6833333333333333, 'X[0] <= 0.154\nsquared_error = 0.001\nsamples = 61\nvalue = 3.04'),
#  Text(0.009879487288676915, 0.65, 'X[0] <= 0.153\nsquared_error = 0.0\nsamples = 36\nvalue = 3.021'),
#  Text(0.009811352893582592, 0.6166666666666667, 'squared_error = 0.0\nsamples = 13\nvalue = 3.0'),
#  Text(0.00994762168377124, 0.6166666666666667, 'X[10] <= 3.5\nsquared_error = 0.0\nsamples = 23\nvalue = 3.033'),
#  Text(0.009879487288676915, 0.5833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 3.033'),
#  Text(0.010015756078865562, 0.5833333333333334, 'X[10] <= 7.0\nsquared_error = 0.0\nsamples = 22\nvalue = 3.033'),
#  Text(0.00994762168377124, 0.55, 'squared_error = 0.0\nsamples = 1\nvalue = 3.033'),
#  Text(0.010083890473959885, 0.55, 'X[9] <= 0.5\nsquared_error = 0.0\nsamples = 21\nvalue = 3.033'),
#  Text(0.010015756078865562, 0.5166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 3.033'),
#  Text(0.01015202486905421, 0.5166666666666667, 'X[6] <= 2008.5\nsquared_error = 0.0\nsamples = 20\nvalue = 3.033'),
#  Text(0.010015756078865562, 0.48333333333333334, 'X[9] <= 10.5\nsquared_error = 0.0\nsamples = 18\nvalue = 3.033'),
#  Text(0.00994762168377124, 0.45, 'squared_error = -0.0\nsamples = 7\nvalue = 3.033'),
#  Text(0.010083890473959885, 0.45, 'X[6] <= 2007.5\nsquared_error = 0.0\nsamples = 11\nvalue = 3.033'),
#  Text(0.010015756078865562, 0.4166666666666667, 'squared_error = 0.0\nsamples = 8\nvalue = 3.033'),
#  Text(0.01015202486905421, 0.4166666666666667, 'squared_error = -0.0\nsamples = 3\nvalue = 3.033'),
#  Text(0.010288293659242857, 0.48333333333333334, 'X[8] <= 16.5\nsquared_error = 0.0\nsamples = 2\nvalue = 3.033'),
#  Text(0.010220159264148532, 0.45, 'squared_error = 0.0\nsamples = 1\nvalue = 3.033'),
#  Text(0.01035642805433718, 0.45, 'squared_error = 0.0\nsamples = 1\nvalue = 3.033'),
#  Text(0.010288293659242857, 0.65, 'X[9] <= 3.5\nsquared_error = 0.0\nsamples = 25\nvalue = 3.067'),
#  Text(0.010220159264148532, 0.6166666666666667, 'X[2] <= 240.515\nsquared_error = 0.0\nsamples = 11\nvalue = 3.067'),
#  Text(0.01015202486905421, 0.5833333333333334, 'squared_error = 0.0\nsamples = 4\nvalue = 3.067'),
#  Text(0.010288293659242857, 0.5833333333333334, 'X[7] <= 4.0\nsquared_error = 0.0\nsamples = 7\nvalue = 3.067'),
#  Text(0.010220159264148532, 0.55, 'squared_error = 0.0\nsamples = 1\nvalue = 3.067'),
#  Text(0.01035642805433718, 0.55, 'squared_error = 0.0\nsamples = 6\nvalue = 3.067'),
#  Text(0.01035642805433718, 0.6166666666666667, 'squared_error = -0.0\nsamples = 14\nvalue = 3.067'),
#  Text(0.010492696844525827, 0.6833333333333333, 'X[0] <= 0.157\nsquared_error = 0.0\nsamples = 51\nvalue = 3.131'),
#  Text(0.010424562449431504, 0.65, 'squared_error = -0.0\nsamples = 13\nvalue = 3.1'),
#  Text(0.010560831239620152, 0.65, 'X[0] <= 0.158\nsquared_error = 0.0\nsamples = 38\nvalue = 3.142'),
#  Text(0.010492696844525827, 0.6166666666666667, 'squared_error = -0.0\nsamples = 28\nvalue = 3.133'),
#  Text(0.010628965634714474, 0.6166666666666667, 'squared_error = -0.0\nsamples = 10\nvalue = 3.167'),
#  Text(0.014256057573563855, 0.8166666666666667, 'X[0] <= 0.109\nsquared_error = 0.355\nsamples = 850\nvalue = 1.399'),
#  Text(0.011259208789336967, 0.7833333333333333, 'X[0] <= 0.085\nsquared_error = 0.021\nsamples = 124\nvalue = 0.363'),
#  Text(0.010969637610186092, 0.75, 'X[5] <= 0.736\nsquared_error = 0.009\nsamples = 117\nvalue = 0.342'),
#  Text(0.010901503215091769, 0.7166666666666667, 'X[0] <= 0.075\nsquared_error = 0.001\nsamples = 116\nvalue = 0.35'),
#  Text(0.010765234424903122, 0.6833333333333333, 'X[0] <= 0.073\nsquared_error = 0.0\nsamples = 67\nvalue = 0.331'),
#  Text(0.010697100029808797, 0.65, 'squared_error = 0.0\nsamples = 4\nvalue = 0.3'),
#  Text(0.010833368819997444, 0.65, 'squared_error = 0.0\nsamples = 63\nvalue = 0.333'),
#  Text(0.011037772005280416, 0.6833333333333333, 'X[0] <= 0.077\nsquared_error = 0.0\nsamples = 49\nvalue = 0.376'),
#  Text(0.010969637610186092, 0.65, 'squared_error = -0.0\nsamples = 38\nvalue = 0.367'),
#  Text(0.011105906400374739, 0.65, 'X[0] <= 0.078\nsquared_error = 0.0\nsamples = 11\nvalue = 0.409'),
#  Text(0.011037772005280416, 0.6166666666666667, 'squared_error = 0.0\nsamples = 9\nvalue = 0.4'),
#  Text(0.011174040795469064, 0.6166666666666667, 'X[2] <= 240.055\nsquared_error = 0.0\nsamples = 2\nvalue = 0.45'),
#  Text(0.011105906400374739, 0.5833333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 0.433'),
#  Text(0.011242175190563386, 0.5833333333333334, 'squared_error = -0.0\nsamples = 1\nvalue = 0.467'),
#  Text(0.011037772005280416, 0.7166666666666667, 'squared_error = -0.0\nsamples = 1\nvalue = -0.633'),
#  Text(0.011548779968487842, 0.75, 'X[0] <= 0.108\nsquared_error = 0.091\nsamples = 7\nvalue = 0.724'),
#  Text(0.01148064557339352, 0.7166666666666667, 'X[10] <= 3.5\nsquared_error = 0.014\nsamples = 6\nvalue = 0.839'),
#  Text(0.011310309585657709, 0.6833333333333333, 'X[9] <= 14.0\nsquared_error = 0.004\nsamples = 2\nvalue = 0.7'),
#  Text(0.011242175190563386, 0.65, 'squared_error = 0.0\nsamples = 1\nvalue = 0.633'),
#  Text(0.011378443980752034, 0.65, 'squared_error = -0.0\nsamples = 1\nvalue = 0.767'),
#  Text(0.011650981561129328, 0.6833333333333333, 'X[5] <= 0.299\nsquared_error = 0.004\nsamples = 4\nvalue = 0.908'),
#  Text(0.011514712770940681, 0.65, 'X[9] <= 7.0\nsquared_error = 0.001\nsamples = 2\nvalue = 0.967'),
#  Text(0.011446578375846356, 0.6166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.011582847166035004, 0.6166666666666667, 'squared_error = -0.0\nsamples = 1\nvalue = 0.933'),
#  Text(0.011787250351317976, 0.65, 'X[2] <= 240.535\nsquared_error = 0.0\nsamples = 2\nvalue = 0.85'),
#  Text(0.011719115956223651, 0.6166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 0.867'),
#  Text(0.011855384746412298, 0.6166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 0.833'),
#  Text(0.011616914363582165, 0.7166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 0.033'),
#  Text(0.017252906357790743, 0.7833333333333333, 'X[11] <= 0.791\nsquared_error = 0.198\nsamples = 726\nvalue = 1.575'),
#  Text(0.015368564493463356, 0.75, 'X[0] <= 0.14\nsquared_error = 0.085\nsamples = 668\nvalue = 1.669'),
#  Text(0.01382276540476089, 0.7166666666666667, 'X[0] <= 0.128\nsquared_error = 0.027\nsamples = 405\nvalue = 1.466'),
#  Text(0.012868883873440361, 0.6833333333333333, 'X[0] <= 0.12\nsquared_error = 0.007\nsamples = 173\nvalue = 1.295'),
#  Text(0.012315291913298982, 0.65, 'X[0] <= 0.117\nsquared_error = 0.003\nsamples = 70\nvalue = 1.218'),
#  Text(0.011991653536600946, 0.6166666666666667, 'X[0] <= 0.114\nsquared_error = 0.002\nsamples = 29\nvalue = 1.164'),
#  Text(0.011821317548865137, 0.5833333333333334, 'X[0] <= 0.112\nsquared_error = 0.001\nsamples = 9\nvalue = 1.111'),
#  Text(0.011753183153770812, 0.55, 'X[2] <= 240.89\nsquared_error = 0.0\nsamples = 4\nvalue = 1.083'),
#  Text(0.01168504875867649, 0.5166666666666667, 'squared_error = 0.0\nsamples = 2\nvalue = 1.067'),
#  Text(0.011821317548865137, 0.5166666666666667, 'squared_error = 0.0\nsamples = 2\nvalue = 1.1'),
#  Text(0.01188945194395946, 0.55, 'squared_error = -0.0\nsamples = 5\nvalue = 1.133'),
#  Text(0.012161989524336754, 0.5833333333333334, 'X[0] <= 0.116\nsquared_error = 0.0\nsamples = 20\nvalue = 1.188'),
#  Text(0.012025720734148107, 0.55, 'X[4] <= 0.178\nsquared_error = 0.0\nsamples = 7\nvalue = 1.167'),
#  Text(0.011957586339053784, 0.5166666666666667, 'X[7] <= 4.0\nsquared_error = 0.0\nsamples = 6\nvalue = 1.167'),
#  Text(0.01188945194395946, 0.48333333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 1.167'),
#  Text(0.012025720734148107, 0.48333333333333334, 'squared_error = 0.0\nsamples = 5\nvalue = 1.167'),
#  Text(0.01209385512924243, 0.5166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 1.167'),
#  Text(0.012298258314525402, 0.55, 'X[9] <= 1.5\nsquared_error = 0.0\nsamples = 13\nvalue = 1.2'),
#  Text(0.012230123919431077, 0.5166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 1.2'),
#  Text(0.012366392709619724, 0.5166666666666667, 'X[10] <= 14.5\nsquared_error = 0.0\nsamples = 12\nvalue = 1.2'),
#  Text(0.012298258314525402, 0.48333333333333334, 'squared_error = 0.0\nsamples = 5\nvalue = 1.2'),
#  Text(0.012434527104714049, 0.48333333333333334, 'X[9] <= 3.5\nsquared_error = 0.0\nsamples = 7\nvalue = 1.2'),
#  Text(0.012366392709619724, 0.45, 'squared_error = 0.0\nsamples = 1\nvalue = 1.2'),
#  Text(0.012502661499808372, 0.45, 'squared_error = -0.0\nsamples = 6\nvalue = 1.2'),
#  Text(0.012638930289997019, 0.6166666666666667, 'X[0] <= 0.119\nsquared_error = 0.0\nsamples = 41\nvalue = 1.255'),
#  Text(0.012570795894902696, 0.5833333333333334, 'squared_error = -0.0\nsamples = 14\nvalue = 1.233'),
#  Text(0.012707064685091342, 0.5833333333333334, 'X[4] <= 0.178\nsquared_error = 0.0\nsamples = 27\nvalue = 1.267'),
#  Text(0.012570795894902696, 0.55, 'X[7] <= 1.5\nsquared_error = 0.0\nsamples = 25\nvalue = 1.267'),
#  Text(0.012502661499808372, 0.5166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 1.267'),
#  Text(0.012638930289997019, 0.5166666666666667, 'X[10] <= 0.5\nsquared_error = 0.0\nsamples = 24\nvalue = 1.267'),
#  Text(0.012570795894902696, 0.48333333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 1.267'),
#  Text(0.012707064685091342, 0.48333333333333334, 'X[2] <= 236.475\nsquared_error = 0.0\nsamples = 23\nvalue = 1.267'),
#  Text(0.012638930289997019, 0.45, 'squared_error = 0.0\nsamples = 1\nvalue = 1.267'),
#  Text(0.012775199080185666, 0.45, 'X[10] <= 4.0\nsquared_error = 0.0\nsamples = 22\nvalue = 1.267'),
#  Text(0.012707064685091342, 0.4166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 1.267'),
#  Text(0.01284333347527999, 0.4166666666666667, 'X[7] <= 4.0\nsquared_error = 0.0\nsamples = 21\nvalue = 1.267'),
#  Text(0.012775199080185666, 0.38333333333333336, 'squared_error = 0.0\nsamples = 5\nvalue = 1.267'),
#  Text(0.012911467870374314, 0.38333333333333336, 'X[7] <= 5.5\nsquared_error = 0.0\nsamples = 16\nvalue = 1.267'),
#  Text(0.01284333347527999, 0.35, 'squared_error = 0.0\nsamples = 1\nvalue = 1.267'),
#  Text(0.012979602265468636, 0.35, 'squared_error = 0.0\nsamples = 15\nvalue = 1.267'),
#  Text(0.01284333347527999, 0.55, 'X[7] <= 8.5\nsquared_error = 0.0\nsamples = 2\nvalue = 1.267'),
#  Text(0.012775199080185666, 0.5166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 1.267'),
#  Text(0.012911467870374314, 0.5166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 1.267'),
#  Text(0.01342247583358174, 0.65, 'X[0] <= 0.123\nsquared_error = 0.002\nsamples = 103\nvalue = 1.348'),
#  Text(0.013184005450751608, 0.6166666666666667, 'X[0] <= 0.122\nsquared_error = 0.0\nsamples = 61\nvalue = 1.311'),
#  Text(0.013047736660562961, 0.5833333333333334, 'X[5] <= 0.299\nsquared_error = 0.0\nsamples = 40\nvalue = 1.3'),
#  Text(0.012979602265468636, 0.55, 'squared_error = 0.0\nsamples = 1\nvalue = 1.3'),
#  Text(0.013115871055657284, 0.55, 'X[2] <= 238.405\nsquared_error = 0.0\nsamples = 39\nvalue = 1.3'),
#  Text(0.013047736660562961, 0.5166666666666667, 'squared_error = 0.0\nsamples = 3\nvalue = 1.3'),
#  Text(0.013184005450751608, 0.5166666666666667, 'X[9] <= 0.5\nsquared_error = 0.0\nsamples = 36\nvalue = 1.3'),
#  Text(0.013115871055657284, 0.48333333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 1.3'),
#  Text(0.013252139845845931, 0.48333333333333334, 'X[2] <= 238.575\nsquared_error = 0.0\nsamples = 35\nvalue = 1.3'),
#  Text(0.013184005450751608, 0.45, 'squared_error = 0.0\nsamples = 1\nvalue = 1.3'),
#  Text(0.013320274240940254, 0.45, 'X[7] <= 2.5\nsquared_error = 0.0\nsamples = 34\nvalue = 1.3'),
#  Text(0.013252139845845931, 0.4166666666666667, 'squared_error = 0.0\nsamples = 5\nvalue = 1.3'),
#  Text(0.013388408636034578, 0.4166666666666667, 'X[10] <= 3.5\nsquared_error = 0.0\nsamples = 29\nvalue = 1.3'),
#  Text(0.013320274240940254, 0.38333333333333336, 'squared_error = 0.0\nsamples = 1\nvalue = 1.3'),
#  Text(0.013456543031128901, 0.38333333333333336, 'squared_error = -0.0\nsamples = 28\nvalue = 1.3'),
#  Text(0.013320274240940254, 0.5833333333333334, 'X[2] <= 240.84\nsquared_error = 0.0\nsamples = 21\nvalue = 1.333'),
#  Text(0.013252139845845931, 0.55, 'squared_error = 0.0\nsamples = 3\nvalue = 1.333'),
#  Text(0.013388408636034578, 0.55, 'squared_error = -0.0\nsamples = 18\nvalue = 1.333'),
#  Text(0.013660946216411873, 0.6166666666666667, 'X[0] <= 0.126\nsquared_error = 0.001\nsamples = 42\nvalue = 1.401'),
#  Text(0.013592811821317548, 0.5833333333333334, 'X[0] <= 0.125\nsquared_error = 0.0\nsamples = 28\nvalue = 1.385'),
#  Text(0.013524677426223226, 0.55, 'squared_error = -0.0\nsamples = 13\nvalue = 1.367'),
#  Text(0.013660946216411873, 0.55, 'X[10] <= 3.5\nsquared_error = 0.0\nsamples = 15\nvalue = 1.4'),
#  Text(0.013592811821317548, 0.5166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 1.4'),
#  Text(0.013729080611506196, 0.5166666666666667, 'X[8] <= 16.5\nsquared_error = 0.0\nsamples = 14\nvalue = 1.4'),
#  Text(0.013660946216411873, 0.48333333333333334, 'squared_error = -0.0\nsamples = 7\nvalue = 1.4'),
#  Text(0.01379721500660052, 0.48333333333333334, 'X[6] <= 2008.5\nsquared_error = 0.0\nsamples = 7\nvalue = 1.4'),
#  Text(0.013729080611506196, 0.45, 'squared_error = 0.0\nsamples = 5\nvalue = 1.4'),
#  Text(0.013865349401694843, 0.45, 'squared_error = -0.0\nsamples = 2\nvalue = 1.4'),
#  Text(0.013729080611506196, 0.5833333333333334, 'squared_error = -0.0\nsamples = 14\nvalue = 1.433'),
#  Text(0.01477664693608142, 0.6833333333333333, 'X[0] <= 0.134\nsquared_error = 0.004\nsamples = 232\nvalue = 1.593'),
#  Text(0.014240088574713622, 0.65, 'X[0] <= 0.131\nsquared_error = 0.001\nsamples = 92\nvalue = 1.525'),
#  Text(0.014069752586977813, 0.6166666666666667, 'X[0] <= 0.129\nsquared_error = 0.0\nsamples = 37\nvalue = 1.488'),
#  Text(0.01400161819188349, 0.5833333333333334, 'X[6] <= 2009.5\nsquared_error = 0.0\nsamples = 13\nvalue = 1.467'),
#  Text(0.013933483796789166, 0.55, 'X[10] <= 13.5\nsquared_error = 0.0\nsamples = 11\nvalue = 1.467'),
#  Text(0.013865349401694843, 0.5166666666666667, 'squared_error = 0.0\nsamples = 2\nvalue = 1.467'),
#  Text(0.01400161819188349, 0.5166666666666667, 'X[2] <= 238.435\nsquared_error = 0.0\nsamples = 9\nvalue = 1.467'),
#  Text(0.013933483796789166, 0.48333333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 1.467'),
# ...
#  Text(0.030149469829238173, 0.5166666666666667, 'squared_error = 0.0\nsamples = 3\nvalue = 3.033'),
#  Text(0.03028573861942682, 0.5166666666666667, 'X[8] <= 4.0\nsquared_error = 0.0\nsamples = 35\nvalue = 3.033'),
#  Text(0.030217604224332496, 0.48333333333333334, 'squared_error = 0.0\nsamples = 2\nvalue = 3.033'),
#  Text(0.030353873014521145, 0.48333333333333334, 'X[8] <= 7.5\nsquared_error = 0.0\nsamples = 33\nvalue = 3.033'),
#  Text(0.03028573861942682, 0.45, 'squared_error = 0.0\nsamples = 3\nvalue = 3.033'),
#  Text(0.030422007409615467, 0.45, 'X[2] <= 239.52\nsquared_error = 0.0\nsamples = 30\nvalue = 3.033'),
#  Text(0.030353873014521145, 0.4166666666666667, 'squared_error = 0.0\nsamples = 2\nvalue = 3.033'),
#  Text(0.03049014180470979, 0.4166666666666667, 'X[9] <= 3.5\nsquared_error = 0.0\nsamples = 28\nvalue = 3.033'),
#  Text(0.030422007409615467, 0.38333333333333336, 'squared_error = 0.0\nsamples = 3\nvalue = 3.033'),
#  Text(0.030558276199804113, 0.38333333333333336, 'X[6] <= 2008.5\nsquared_error = 0.0\nsamples = 25\nvalue = 3.033'),
#  Text(0.03049014180470979, 0.35, 'squared_error = 0.0\nsamples = 5\nvalue = 3.033'),
#  Text(0.030626410594898436, 0.35, 'X[2] <= 239.93\nsquared_error = 0.0\nsamples = 20\nvalue = 3.033'),
#  Text(0.030558276199804113, 0.31666666666666665, 'squared_error = 0.0\nsamples = 2\nvalue = 3.033'),
#  Text(0.030694544989992762, 0.31666666666666665, 'X[1] <= 0.052\nsquared_error = 0.0\nsamples = 18\nvalue = 3.033'),
#  Text(0.030626410594898436, 0.2833333333333333, 'squared_error = 0.0\nsamples = 4\nvalue = 3.033'),
#  Text(0.030762679385087085, 0.2833333333333333, 'X[7] <= 3.5\nsquared_error = 0.0\nsamples = 14\nvalue = 3.033'),
#  Text(0.030694544989992762, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 3.033'),
#  Text(0.030830813780181408, 0.25, 'X[10] <= 16.0\nsquared_error = 0.0\nsamples = 13\nvalue = 3.033'),
#  Text(0.030762679385087085, 0.21666666666666667, 'squared_error = 0.0\nsamples = 2\nvalue = 3.033'),
#  Text(0.03089894817527573, 0.21666666666666667, 'X[2] <= 241.27\nsquared_error = 0.0\nsamples = 11\nvalue = 3.033'),
#  Text(0.030830813780181408, 0.18333333333333332, 'squared_error = 0.0\nsamples = 1\nvalue = 3.033'),
#  Text(0.030967082570370053, 0.18333333333333332, 'X[2] <= 241.79\nsquared_error = 0.0\nsamples = 10\nvalue = 3.033'),
#  Text(0.03089894817527573, 0.15, 'squared_error = 0.0\nsamples = 1\nvalue = 3.033'),
#  Text(0.03103521696546438, 0.15, 'squared_error = 0.0\nsamples = 9\nvalue = 3.033'),
#  Text(0.0306604777924456, 0.6166666666666667, 'X[7] <= 6.5\nsquared_error = 0.0\nsamples = 61\nvalue = 3.067'),
#  Text(0.030422007409615467, 0.5833333333333334, 'X[2] <= 239.31\nsquared_error = 0.0\nsamples = 30\nvalue = 3.067'),
#  Text(0.030353873014521145, 0.55, 'squared_error = 0.0\nsamples = 1\nvalue = 3.067'),
#  Text(0.03049014180470979, 0.55, 'X[10] <= 15.0\nsquared_error = 0.0\nsamples = 29\nvalue = 3.067'),
#  Text(0.030422007409615467, 0.5166666666666667, 'squared_error = 0.0\nsamples = 6\nvalue = 3.067'),
#  Text(0.030558276199804113, 0.5166666666666667, 'X[7] <= 4.5\nsquared_error = 0.0\nsamples = 23\nvalue = 3.067'),
#  Text(0.03049014180470979, 0.48333333333333334, 'squared_error = 0.0\nsamples = 14\nvalue = 3.067'),
#  Text(0.030626410594898436, 0.48333333333333334, 'X[10] <= 18.5\nsquared_error = 0.0\nsamples = 9\nvalue = 3.067'),
#  Text(0.030558276199804113, 0.45, 'squared_error = 0.0\nsamples = 1\nvalue = 3.067'),
#  Text(0.030694544989992762, 0.45, 'squared_error = 0.0\nsamples = 8\nvalue = 3.067'),
#  Text(0.03089894817527573, 0.5833333333333334, 'X[9] <= 4.5\nsquared_error = 0.0\nsamples = 31\nvalue = 3.067'),
#  Text(0.030762679385087085, 0.55, 'X[10] <= 1.5\nsquared_error = 0.0\nsamples = 16\nvalue = 3.067'),
#  Text(0.030694544989992762, 0.5166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 3.067'),
#  Text(0.030830813780181408, 0.5166666666666667, 'X[6] <= 2007.5\nsquared_error = 0.0\nsamples = 15\nvalue = 3.067'),
#  Text(0.030762679385087085, 0.48333333333333334, 'squared_error = 0.0\nsamples = 1\nvalue = 3.067'),
#  Text(0.03089894817527573, 0.48333333333333334, 'squared_error = 0.0\nsamples = 14\nvalue = 3.067'),
#  Text(0.03103521696546438, 0.55, 'X[2] <= 240.04\nsquared_error = 0.0\nsamples = 15\nvalue = 3.067'),
#  Text(0.030967082570370053, 0.5166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 3.067'),
#  Text(0.031103351360558702, 0.5166666666666667, 'squared_error = 0.0\nsamples = 14\nvalue = 3.067'),
#  Text(0.03130775454584167, 0.65, 'X[0] <= 0.197\nsquared_error = 0.0\nsamples = 108\nvalue = 3.115'),
#  Text(0.031171485755653025, 0.6166666666666667, 'X[7] <= 4.5\nsquared_error = 0.0\nsamples = 58\nvalue = 3.1'),
#  Text(0.031103351360558702, 0.5833333333333334, 'squared_error = -0.0\nsamples = 14\nvalue = 3.1'),
#  Text(0.031239620150747348, 0.5833333333333334, 'X[2] <= 237.12\nsquared_error = 0.0\nsamples = 44\nvalue = 3.1'),
#  Text(0.031171485755653025, 0.55, 'squared_error = 0.0\nsamples = 2\nvalue = 3.1'),
#  Text(0.03130775454584167, 0.55, 'X[10] <= 0.5\nsquared_error = 0.0\nsamples = 42\nvalue = 3.1'),
#  Text(0.031239620150747348, 0.5166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 3.1'),
#  Text(0.03137588894093599, 0.5166666666666667, 'X[9] <= 0.5\nsquared_error = 0.0\nsamples = 41\nvalue = 3.1'),
#  Text(0.031239620150747348, 0.48333333333333334, 'X[4] <= 0.178\nsquared_error = 0.0\nsamples = 3\nvalue = 3.1'),
#  Text(0.031171485755653025, 0.45, 'X[10] <= 36.5\nsquared_error = 0.0\nsamples = 2\nvalue = 3.1'),
#  Text(0.031103351360558702, 0.4166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 3.1'),
#  Text(0.031239620150747348, 0.4166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 3.1'),
#  Text(0.03130775454584167, 0.45, 'squared_error = 0.0\nsamples = 1\nvalue = 3.1'),
#  Text(0.031512157731124646, 0.48333333333333334, 'X[8] <= 15.0\nsquared_error = 0.0\nsamples = 38\nvalue = 3.1'),
#  Text(0.03144402333603032, 0.45, 'squared_error = -0.0\nsamples = 14\nvalue = 3.1'),
#  Text(0.03158029212621897, 0.45, 'X[8] <= 16.5\nsquared_error = 0.0\nsamples = 24\nvalue = 3.1'),
#  Text(0.031512157731124646, 0.4166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 3.1'),
#  ...]
# Error in callback <function flush_figures at 0x0000029A9B6A5D30> (for post_execute):
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# ~\anaconda3\lib\inspect.py in _bind(self, args, kwargs, partial)
#    2919             try:
# -> 2920                 arg_val = next(arg_vals)
#    2921             except StopIteration:
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\matplotlib_inline\backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~\anaconda3\lib\site-packages\matplotlib_inline\backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~\anaconda3\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2232             if bbox_inches:
#    2233                 if bbox_inches == "tight":
# -> 2234                     bbox_inches = self.figure.get_tightbbox(
#    2235                         renderer, bbox_extra_artists=bbox_extra_artists)
#    2236                     if pad_inches is None:
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    1637
#    1638         for a in artists:
# -> 1639             bbox = a.get_tightbbox(renderer)
#    1640             if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    1641                 bb.append(bbox)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4475                     # this artist
#    4476                     continue
# -> 4477             bbox = a.get_tightbbox(renderer)
#    4478             if (bbox is not None
#    4479                     and 0 < bbox.width < np.inf
#
# ~\anaconda3\lib\site-packages\matplotlib\text.py in get_tightbbox(self, renderer)
#    2000         if not self._check_xy(renderer):
#    2001             return Bbox.null()
# -> 2002         return super().get_tightbbox(renderer)
#    2003
#    2004
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in get_tightbbox(self, renderer)
#     304             The enclosing bounding box (in figure pixel coordinates).
#     305         """
# --> 306         bbox = self.get_window_extent(renderer)
#     307         if self.get_clip_on():
#     308             clip_box = self.get_clip_box()
#
# ~\anaconda3\lib\site-packages\matplotlib\text.py in get_window_extent(self, renderer)
#    1992
#    1993         if self.arrow_patch is not None:
# -> 1994             bboxes.append(self.arrow_patch.get_window_extent())
#    1995
#    1996         return Bbox.union(bboxes)
#
# ~\anaconda3\lib\site-packages\matplotlib\patches.py in get_window_extent(self, renderer)
#     619
#     620     def get_window_extent(self, renderer=None):
# --> 621         return self.get_path().get_extents(self.get_transform())
#     622
#     623     def _convert_xy_units(self, xy):
#
# ~\anaconda3\lib\site-packages\matplotlib\patches.py in get_path(self)
#    4201         in display coordinates.
#    4202         """
# -> 4203         _path, fillable = self.get_path_in_displaycoord()
#    4204         if np.iterable(fillable):
#    4205             _path = Path.make_compound_path(*_path)
#
# ~\anaconda3\lib\site-packages\matplotlib\patches.py in get_path_in_displaycoord(self)
#    4214             posB = self._convert_xy_units(self._posA_posB[1])
#    4215             (posA, posB) = self.get_transform().transform((posA, posB))
# -> 4216             _path = self.get_connectionstyle()(posA, posB,
#    4217                                                patchA=self.patchA,
#    4218                                                patchB=self.patchB,
#
# ~\anaconda3\lib\site-packages\matplotlib\patches.py in __call__(self, posA, posB, shrinkA, shrinkB, patchA, patchB)
#    2524             """
#    2525             path = self.connect(posA, posB)
# -> 2526             clipped_path = self._clip(path, patchA, patchB)
#    2527             shrunk_path = self._shrink(clipped_path, shrinkA, shrinkB)
#    2528             return shrunk_path
#
# ~\anaconda3\lib\site-packages\matplotlib\patches.py in _clip(self, path, patchA, patchB)
#    2479
#    2480                 try:
# -> 2481                     left, right = split_path_inout(path, insideA)
#    2482                 except ValueError:
#    2483                     right = path
#
# ~\anaconda3\lib\site-packages\matplotlib\bezier.py in split_path_inout(path, inside, tolerance, reorder_inout)
#     369
#     370     bp = bezier_path.reshape((-1, 2))
# --> 371     left, right = split_bezier_intersecting_with_closedpath(
#     372         bp, inside, tolerance)
#     373     if len(left) == 2:
#
# ~\anaconda3\lib\site-packages\matplotlib\bezier.py in split_bezier_intersecting_with_closedpath(bezier, inside_closedpath, tolerance)
#     332     bezier_point_at_t = bz.point_at_t
#     333
# --> 334     t0, t1 = find_bezier_t_intersecting_with_closedpath(
#     335         bezier_point_at_t, inside_closedpath, tolerance=tolerance)
#     336
#
# ~\anaconda3\lib\site-packages\matplotlib\bezier.py in find_bezier_t_intersecting_with_closedpath(bezier_point_at_t, inside_closedpath, t0, t1, tolerance)
#     152     end = bezier_point_at_t(t1)
#     153
# --> 154     start_inside = inside_closedpath(start)
#     155     end_inside = inside_closedpath(end)
#     156
#
# ~\anaconda3\lib\site-packages\matplotlib\patches.py in insideA(xy_display)
#    2476                 def insideA(xy_display):
#    2477                     xy_event = ConnectionStyle._Base.SimpleEvent(xy_display)
# -> 2478                     return patchA.contains(xy_event)[0]
#    2479
#    2480                 try:
#
# ~\anaconda3\lib\site-packages\matplotlib\patches.py in contains(self, mouseevent, radius)
#     148         codes = self.get_path().codes
#     149         if codes is not None:
# --> 150             vertices = self.get_path().vertices
#     151             # if the current path is concatenated by multiple sub paths.
#     152             # get the indexes of the starting code(MOVETO) of all sub paths
#
# ~\anaconda3\lib\site-packages\matplotlib\patches.py in get_path(self)
#    3802                 "old call signature will be removed %(removal)s.")
#    3803         else:
# -> 3804             path = boxstyle(x, y, width, height, m_scale)
#    3805         vertices, codes = path.vertices, path.codes
#    3806         # Restore the height.
#
# ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     404     @functools.wraps(func)
#     405     def wrapper(*inner_args, **inner_kwargs):
# --> 406         arguments = signature.bind(*inner_args, **inner_kwargs).arguments
#     407         if is_varargs and arguments.get(name):
#     408             warn_deprecated(
#
# ~\anaconda3\lib\inspect.py in bind(self, *args, **kwargs)
#    3041         if the passed arguments can not be bound.
#    3042         """
# -> 3043         return self._bind(args, kwargs)
#    3044
#    3045     def bind_partial(self, /, *args, **kwargs):
#
# ~\anaconda3\lib\inspect.py in _bind(self, args, kwargs, partial)
#    2928                     break
#    2929                 else:
# -> 2930                     if param.kind == _VAR_POSITIONAL:
#    2931                         # That's OK, just empty *args.  Let's start parsing
#    2932                         # kwargs
#
# KeyboardInterrupt:

# %%
model.score(X_train,y_train)
# Out:
# 1.0

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# 0.9216680134680136
# 0.14241212121212266
# 0.9600354230277202

# %%
score = r2_score(y_test,y_pred)
print(score)
# Out:
# 0.9897545166433215

# %%
## Adjusted R2 need to write
adjR = 1 - ( 1-score ) * ( len(y) - 1 ) / ( len(y) - X.shape[1] - 1 )
print(adjR)
# Out:
# 0.9897520570878314

# %% [markdown]
# ### Test data has the accuracy of 98%

# %% [markdown]
# ### Thank you
